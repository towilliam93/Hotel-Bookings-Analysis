# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing Data
path = r'C:\Users\arafo\CareerFoundry\Hotel Booking Analysis'
df_bookings = pd.read_csv(os.path.join(path, '02 - Data', 'Original Data', 'hotel_bookings.csv'), index_col = False)
df_countries = pd.read_csv(os.path.join(path, '02 - Data', 'Original Data', 'country_code.csv'), index_col = False)

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
df_bookings.head(15)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
#
# ...

# %%
df_bookings.tail(15)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119375  City Hotel            0        200               2017
# 119376  City Hotel            0        165               2017
# 119377  City Hotel            0        185               2017
# 119378  City Hotel            0        247               2017
# 119379  City Hotel            0        109               2017
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# ...

# %%
# Checking countries of origins
df_bookings['country'].value_counts(dropna = False)
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# ITA     3766
# IRL     3375
# BEL     2342
# BRA     2224
# NLD     2104
# USA     2097
# CHE     1730
# CN      1279
# AUT     1263
# SWE     1024
# CHN      999
# POL      919
# ISR      669
# RUS      632
# NOR      607
# ROU      500
# NaN      488
# FIN      447
# DNK      435
# AUS      426
# AGO      362
# LUX      287
# MAR      259
# TUR      248
# HUN      230
# ARG      214
# JPN      197
# CZE      171
# IND      152
# KOR      133
# GRC      128
# DZA      103
# SRB      101
# HRV      100
# MEX       85
# EST       83
# IRN       83
# LTU       81
# ZAF       80
# BGR       75
# NZL       74
# COL       71
# UKR       68
# MOZ       67
# CHL       65
# SVK       65
# THA       59
# SVN       57
# ISL       57
# LVA       55
# ARE       51
# CYP       51
# TWN       51
# SAU       48
# PHL       40
# TUN       39
# SGP       39
# IDN       35
# NGA       34
# EGY       32
# URY       32
# ...

# %%
df_countries
# Out:
#                                              name alpha-2 alpha-3  \
# 0                                     Afghanistan      AF     AFG
# 1                                   Åland Islands      AX     ALA
# 2                                         Albania      AL     ALB
# 3                                         Algeria      DZ     DZA
# 4                                  American Samoa      AS     ASM
# 5                                         Andorra      AD     AND
# 6                                          Angola      AO     AGO
# 7                                        Anguilla      AI     AIA
# 8                                      Antarctica      AQ     ATA
# 9                             Antigua and Barbuda      AG     ATG
# 10                                      Argentina      AR     ARG
# 11                                        Armenia      AM     ARM
# 12                                          Aruba      AW     ABW
# ...

# %%
# Dropping unnecessary columns
df_clean_countries = df_countries.drop(['alpha-2', 'country-code', 'iso_3166-2', 'sub-region', 'intermediate-region', 'region-code', 'sub-region-code', 'intermediate-region-code'], axis = 1)

# %%
df_clean_countries
# Out:
#                                              name alpha-3    region
# 0                                     Afghanistan     AFG      Asia
# 1                                   Åland Islands     ALA    Europe
# 2                                         Albania     ALB    Europe
# 3                                         Algeria     DZA    Africa
# 4                                  American Samoa     ASM   Oceania
# 5                                         Andorra     AND    Europe
# 6                                          Angola     AGO    Africa
# 7                                        Anguilla     AIA  Americas
# 8                                      Antarctica     ATA       NaN
# 9                             Antigua and Barbuda     ATG  Americas
# 10                                      Argentina     ARG  Americas
# 11                                        Armenia     ARM      Asia
# 12                                          Aruba     ABW  Americas
# ...

# %%
df_bookings.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
# Dropping Unnecessary columns
df_bookings2 = df_bookings.drop(['reserved_room_type','assigned_room_type','agent','company'], axis = 1)

# %%
df_bookings2.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
# Renaming Countries' alpha-3 column to enable merging
df_clean_countries.rename(columns = {'alpha-3' : 'country'}, inplace = True)
df_clean_countries.rename(columns = {'name' : 'country_name'}, inplace = True)

# %%
df_clean_countries.head(5)
# Out:
#      country_name country   region
# 0     Afghanistan     AFG     Asia
# 1   Åland Islands     ALA   Europe
# 2         Albania     ALB   Europe
# 3         Algeria     DZA   Africa
# 4  American Samoa     ASM  Oceania

# %%
# Merging clean_countries onto bookings2
df_bookings3 = df_bookings2.merge(df_clean_countries, on = 'country', indicator = True)

# %%
df_bookings3.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          0               2015               July
# 3  Resort Hotel            0          9               2015               July
# 4  Resort Hotel            1         85               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# Removed _merge column

df_bookings3 = df_bookings3.drop(['_merge'], axis = 1)

# %%
df_bookings3.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          0               2015               July
# 3  Resort Hotel            0          9               2015               July
# 4  Resort Hotel            1         85               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df_bookings2.shape
# Out:
# (119390, 28)

# %%
df_bookings3.shape
# Out:
# (117620, 30)

# %%
# Checking countries of origins
df_bookings2['country'].value_counts(dropna = False).sort_index(ascending=True)
# Out:
# ABW        2
# AGO      362
# AIA        1
# ALB       12
# AND        7
# ARE       51
# ARG      214
# ARM        8
# ASM        1
# ATA        2
# ATF        1
# AUS      426
# AUT     1263
# AZE       17
# BDI        1
# BEL     2342
# BEN        3
# BFA        1
# BGD       12
# BGR       75
# BHR        5
# BHS        1
# BIH       13
# BLR       26
# BOL       10
# BRA     2224
# BRB        4
# BWA        1
# CAF        5
# CHE     1730
# CHL       65
# CHN      999
# CIV        6
# CMR       10
# CN      1279
# COL       71
# COM        2
# CPV       24
# CRI       19
# CUB        8
# CYM        1
# CYP       51
# CZE      171
# DEU     7287
# DJI        1
# DMA        1
# DNK      435
# DOM       14
# DZA      103
# ECU       27
# EGY       32
# ESP     8568
# EST       83
# ETH        3
# FIN      447
# FJI        1
# FRA    10415
# FRO        5
# GAB        4
# GBR    12129
# GEO       22
# GGY        3
# GHA        4
# GIB       18
# GLP        2
# GNB        9
# ...

# %%
df_bookings3['country'].value_counts(dropna = False).sort_index(ascending=True)
# Out:
# ABW        2
# AGO      362
# AIA        1
# ALB       12
# AND        7
# ARE       51
# ARG      214
# ARM        8
# ASM        1
# ATA        2
# ATF        1
# AUS      426
# AUT     1263
# AZE       17
# BDI        1
# BEL     2342
# BEN        3
# BFA        1
# BGD       12
# BGR       75
# BHR        5
# BHS        1
# BIH       13
# BLR       26
# BOL       10
# BRA     2224
# BRB        4
# BWA        1
# CAF        5
# CHE     1730
# CHL       65
# CHN      999
# CIV        6
# CMR       10
# COL       71
# COM        2
# CPV       24
# CRI       19
# CUB        8
# CYM        1
# CYP       51
# CZE      171
# DEU     7287
# DJI        1
# DMA        1
# DNK      435
# DOM       14
# DZA      103
# ECU       27
# EGY       32
# ESP     8568
# EST       83
# ETH        3
# FIN      447
# FJI        1
# FRA    10415
# FRO        5
# GAB        4
# GBR    12129
# GEO       22
# GGY        3
# GHA        4
# GIB       18
# GLP        2
# GNB        9
# GRC      128
# ...

# %% [markdown]
# - Bookings 3 Missing CN - China values, TMP - East Timor is now TLS - Timor-Leste, and NaN values
# - NaN Values total 488, willing to drop because of no country value
# - Change values, update
# - Re-add CN and TMP values

# %%
df_bookings2['country'] = df_bookings2['country'].replace({'CN': 'CHN'})
df_bookings2['country'] = df_bookings2['country'].replace({'TMP': 'TLS'})

# %%
# Re-merging after changes
df_bookings4 = df_bookings2.merge(df_clean_countries, on = 'country', indicator = True)

# %%
df_bookings4.shape
# Out:
# (118902, 31)

# %% [markdown]
# - 119390 - 488 NaN values = 118902

# %%
# Drop _merged column
df_bookings4 = df_bookings4.drop(['_merge'], axis = 1)

# %%
# Checking countries of origins
df_bookings4['country'].value_counts(dropna = False).sort_index(ascending=True)
# Out:
# ABW        2
# AGO      362
# AIA        1
# ALB       12
# AND        7
# ARE       51
# ARG      214
# ARM        8
# ASM        1
# ATA        2
# ATF        1
# AUS      426
# AUT     1263
# AZE       17
# BDI        1
# BEL     2342
# BEN        3
# BFA        1
# BGD       12
# BGR       75
# BHR        5
# BHS        1
# BIH       13
# BLR       26
# BOL       10
# BRA     2224
# BRB        4
# BWA        1
# CAF        5
# CHE     1730
# CHL       65
# CHN     2278
# CIV        6
# CMR       10
# COL       71
# COM        2
# CPV       24
# CRI       19
# CUB        8
# CYM        1
# CYP       51
# CZE      171
# DEU     7287
# DJI        1
# DMA        1
# DNK      435
# DOM       14
# DZA      103
# ECU       27
# EGY       32
# ESP     8568
# EST       83
# ETH        3
# FIN      447
# FJI        1
# FRA    10415
# FRO        5
# GAB        4
# GBR    12129
# GEO       22
# GGY        3
# GHA        4
# GIB       18
# GLP        2
# GNB        9
# GRC      128
# ...

# %%
# Checking for missing Values
df_bookings4.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          4
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# ...

# %%
df_bookings4[df_bookings4['region'].isnull() == True]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 118887  City Hotel            0         34               2016
# 118888  City Hotel            0          7               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 118887            October                        42
# 118888            January                         3
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 118887                         13                        0
# 118888                         20                        0
#
#         stays_in_week_nights  adults  children  babies meal country  \
# 118887                     2       1       0.0       0   BB     ATA
# 118888                     2       1       0.0       0   SC     ATA
#
#        market_segment distribution_channel  is_repeated_guest  \
# 118887         Direct               Direct                  0
# 118888      Online TA                TA/TO                  0
#
# ...

# %% [markdown]
# - Two bookings from Antarctica, which doesn't have a region, is fine.

# %%
# Checking for duplicate data
duplicates = df_bookings4[df_bookings4.duplicated()]

# %%
duplicates.head(5)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 11   Resort Hotel            0         72               2015
# 72   Resort Hotel            1          5               2015
# 117  Resort Hotel            1          1               2015
# 139  Resort Hotel            0         91               2015
# 141  Resort Hotel            0         30               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 11                July                        27                          1
# 72                July                        28                          5
# 117               July                        28                          8
# 139               July                        28                         10
# 141               July                        28                         10
#
#      stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# ...

# %%
df_bookings4.head(15)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          0               2015
# 3   Resort Hotel            0          9               2015
# 4   Resort Hotel            1         85               2015
# 5   Resort Hotel            1         75               2015
# 6   Resort Hotel            1         23               2015
# 7   Resort Hotel            0         35               2015
# 8   Resort Hotel            0         37               2015
# 9   Resort Hotel            0         37               2015
# 10  Resort Hotel            0         72               2015
# 11  Resort Hotel            0         72               2015
# 12  Resort Hotel            0         72               2015
# 13  Resort Hotel            0         78               2015
# 14  Resort Hotel            1         60               2015
#
# ...

# %%
df_bookings.head(25)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %%
df_bookings.shape
# Out:
# (119390, 32)

# %%
df_bookings4.shape
# Out:
# (118902, 30)

# %%
duplicates.shape
# Out:
# (33006, 30)

# %%
# Dropping duplicates, which makes up over 25% of the dataset
df_bookings_nodupes = df_bookings4.drop_duplicates()

# %%
df_bookings_nodupes.head(25)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          0               2015
# 3   Resort Hotel            0          9               2015
# 4   Resort Hotel            1         85               2015
# 5   Resort Hotel            1         75               2015
# 6   Resort Hotel            1         23               2015
# 7   Resort Hotel            0         35               2015
# 8   Resort Hotel            0         37               2015
# 9   Resort Hotel            0         37               2015
# 10  Resort Hotel            0         72               2015
# 12  Resort Hotel            0         72               2015
# 13  Resort Hotel            0         78               2015
# 14  Resort Hotel            1         60               2015
# 15  Resort Hotel            0         77               2015
# ...

# %%
df_bookings_nodupes.shape
# Out:
# (85896, 30)

# %%
# 4 missing values in Children, assumption that no values means no children.
df_bookings_nodupes['children'] = df_bookings_nodupes['children'].fillna(0)
# Out:
# C:\Users\arafo\AppData\Local\Temp\ipykernel_11896\4143271507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bookings_nodupes['children'] = df_bookings_nodupes['children'].fillna(0)

# %%
df_bookings_nodupes.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# ...

# %%
df_bookings_nodupes.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          0               2015               July
# 3  Resort Hotel            0          9               2015               July
# 4  Resort Hotel            1         85               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# Renaming adr to average_daily_rate
df_bookings_nodupes.rename(columns = {'adr' : 'average_daily_rate'}, inplace = True)
# Out:
# C:\Users\arafo\AppData\Local\Temp\ipykernel_11896\689024041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bookings_nodupes.rename(columns = {'adr' : 'average_daily_rate'}, inplace = True)

# %%
df_bookings_nodupes.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          0               2015               July
# 3  Resort Hotel            0          9               2015               July
# 4  Resort Hotel            1         85               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# Check for mixed types
for col in df_bookings_nodupes.columns.tolist():
  weird = (df_bookings_nodupes[[col]].applymap(type) != df_bookings_nodupes[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_bookings_nodupes[weird]) > 0:
    print (col)
# Out:
# region

# %% [markdown]
# - Region has null values because of Antarctica

# %%
df_bookings_nodupes['region'] = df_bookings_nodupes['region'].fillna('Antarctica')
# Out:
# C:\Users\arafo\AppData\Local\Temp\ipykernel_11896\1599727519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bookings_nodupes['region'] = df_bookings_nodupes['region'].fillna('Antarctica')

# %%
# Check for mixed types
for col in df_bookings_nodupes.columns.tolist():
  weird = (df_bookings_nodupes[[col]].applymap(type) != df_bookings_nodupes[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_bookings_nodupes[weird]) > 0:
    print (col)

# %%
df_bookings_nodupes.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# average_daily_rate                0
# required_car_parking_spaces       0
# total_of_special_requests         0
# ...

# %%
df_bookings_nodupes.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# deposit_type                       object
# days_in_waiting_list                int64
# ...

# %%
# Change children from float to int
df_bookings_nodupes['children'] = df_bookings_nodupes['children'].astype('int64')
# Out:
# C:\Users\arafo\AppData\Local\Temp\ipykernel_11896\30105098.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bookings_nodupes['children'] = df_bookings_nodupes['children'].astype('int64')

# %%
df_bookings_nodupes['children'].dtypes
# Out:
# dtype('int64')

# %%
df_bookings_nodupes.shape
# Out:
# (85896, 30)

# %%
# Exporting data to csv
df_bookings_nodupes.to_csv(os.path.join(path, '02 - Data','Prepared Data', 'bookings_nodupes.csv'))

# %%
# Exporting as pickle
df_bookings_nodupes.to_pickle(os.path.join(path, '02 - Data','Prepared Data', 'bookings_nodupes.pkl'))
